# %% [markdown]
# ![this is a jpg](ANNnetwork.jpg)

# %%
# %matplotlib inline
import math
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(-1,1,0.02)
y=np.square(x)
z=np.sqrt(x)

plt.plot(x,z)
plt.plot(x,y)
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in sqrt

# %%
# %matplotlib inline
import math
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(-100,100,0.02)
y=1/(np.exp(-x)+1)


plt.plot(x,y)
plt.show()
