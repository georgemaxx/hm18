# %% [markdown]
# # 有一个单细胞生物，生活在糖水和盐水混合物中，糖水盐水在不停的流动，它有两个鞭毛，分别可以感知糖水和盐水，当总浓度到达一定值时，就会吃这些糖水盐水

# %% [markdown]
# ![](神经元.png)  ![](ANN.jpg)

# %% [markdown]
# # 但是，同时吃进糖水和盐水，会造成细胞结石，有损细胞健康
#
#
# # 慢慢地，单细胞生物慢慢和其它细胞一起，组成了多细胞生物，进化出了一个能力，有糖水吃糖水，有盐水吃盐水，同时都有的话就不吃，防止细胞里面无法同时消化两种物体。

# %% [markdown]
# ![](多神经元.png)
# ![](ANNNetwork.jpg)

# %% [markdown]
# # 下面，我们用人工神经元网络来模拟从单细胞到多细胞的进化过程
# # 首先，画出最终的输入输出函数3维曲线。

# %%
画出它的输入输出函数3D图
提示：Z=numpy.logical.xor(X,Y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)

x1=numpy.arange(0,2,1)
x2=numpy.arange(0,2,1)

X,Y=np.meshgrid(x1, x2)    # x-y 平面的网格
Z=numpy.logical_xor(X,Y)

ax.plot_surface(X, Y, Z, rstride = 1, cstride = 1, cmap = plt.get_cmap('rainbow'))
ax.contour(X, Y, Z, offset = -0.5, cmap = 'rainbow')
ax.set_zlim(-1, 1)

plt.show()

print(X)
print(Y)
print(Z)
# Out:
# [[0 1]
#  [0 1]]
# [[0 0]
#  [1 1]]
# [[False  True]
#  [ True False]]

# %% [markdown]
# # 所以，人工神经元有网络有2输入，1输出
#                                             输入层            中间层          输出层
#                                                       L1                L2

# %% [markdown]
# ![](xorann.png)

# %% [markdown]
# # 首先，尝试用单细胞线性加权

# %% [markdown]
# ![](line1ann.png)

# %% [markdown]
# # 定义NN输入输出函数

# %%
import numpy as np

# def sigmod(R):
#     R = 1/(1+np.exp(-R))
#     return R

def NNWadd(x1,x2):
       
    
    print("x1")
    print(x1)
    print("x2")
    print(x2)
    print("B")
    print(B)
    
    wB1 = 
    wB2 = 
    wB3 = 
    wB4 = 
    w11 = 
    w12 = 
    w13 = 
    w14 = 

    
    R=np.add(w1*x1,w2*x2)
    R2=np.add(w3*x1,w4*x2)
    
    print("R")
    print(R)
    R = 1/(1+np.exp(-R))
    R2 = 1/(1+np.exp(-R2))
    R = np.add(w5*R,w6*R2)

    return R

# %%
import numpy as np

x1 = np.arange(0,2,1)
x2 = np.arange(0,2,1)

x,y = np.meshgrid(x1,x2)


print("X","Y")
print(x)
print(y)

NNWadd(x,y)
# Out:
# X Y
# [[0 1]
#  [0 1]]
# [[0 0]
#  [1 1]]
# x1
# [[0 1]
#  [0 1]]
# x2
# [[0 0]
#  [1 1]]
# R
# [[ 0 -7]
#  [ 4 -3]]
# array([[-2.50000000e+00,  1.22654376e-03],
#        [-5.01128566e+00, -2.37129366e-01]])

# %% [markdown]
# # 画出NNWadd的三维图

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)

x1=np.arange(0,2,1)
x2=np.arange(0,2,1)

X,Y=np.meshgrid(x1, x2)    # x-y 平面的网格
     
ZADD=NNWadd(X,Y)

ax.plot_surface(X, Y, ZADD, rstride = 1, cstride = 1, cmap = plt.get_cmap('rainbow'))
ax.contour(X, Y, ZADD, offset = -0.5, cmap = 'rainbow')
ax.set_zlim(-1, 1)

plt.show()

print(ZADD)
# Out:
# x1
# [[0 1]
#  [0 1]]
# x2
# [[0 0]
#  [1 1]]
# R
# [[ 0  4]
#  [-4  0]]
# [[1.         1.55916073]
#  [3.77432409 2.9732286 ]]

# %% [markdown]
# # 分析一下权值的可能性

# %% [markdown]
# ### x1w1   x2w2  输出
# ### 0 x w1  +  0 x w2    =0
# ### 1 x w1  +  0 x w2    =1
# ### 0 x w1  +  1 x w2    =1
# ### 1 x w1  +  1 x w2    =0
#
# # 可以得出w1=1  w2=1
#
# # 但是和第四式严重矛盾

# %% [markdown]
# # 引入更多权值,多加一个细胞

# %% [markdown]
# ![](lin1w3w4.png)

# %% [markdown]
# ### x1w1   x2w2  输出
# ### 0 x w1  +  0 x w2   + 0 x w3 + 0 x w4   = 0
# ### 0 x w1  +  1 x w2   + 0 x w3 + 1 x w4   =1
# ### 1 x w1  +  0 x w2   + 1 x w3 + 0 x w4   =1
# ### 1 x w1  +  1 x w2   + 1 x w3 + 1 x w4   =0
#
# # 求解方程
# ###                                                              = 0
# ###                   w2                            + w4  = 1
# ###       w1                       + w3                   = 1
# ###       w1        +w2            + w3     + w4  = 0
#
# # 试解
# ###                                                             = 0
# ###                   2                                -1     = 1
# ###       2                            -1                     = 1
# ###      2           2               -1             -1      = 2

# %% [markdown]
# # 引入激励函数

# %% [markdown]
# ![](lin1w3w4sig.png)

# %% [markdown]
# # 引入sigmod非线性
# ### sigmod(0)        +            sigmod(0)      = ?
# ### sigmod(2)        +            sigmod(-1)     = ?
# ### sigmod(2)        +            sigmod(-1)     = ?
# ### sigmod(4)        +            sigmod(-2)     = ?
#
# 试计算问号里的值

# %%
x=0
print(1/(1+np.exp(-x)))
x=0
print(1/(1+np.exp(-x)))
x=2
print(1/(1+np.exp(-x)))
x=-1
print(1/(1+np.exp(-x)))
x=4
print(1/(1+np.exp(-x)))
x=-2
print(1/(1+np.exp(-x)))
# Out:
# 0.5
# 0.5
# 0.880797077978
# 0.26894142137
# 0.982013790038
# 0.119202922022

# %% [markdown]
# ### sigmod(0)       +             sigmod(0)      = 0.5  + 0.5  = 1
# ### sigmod(2)       +             sigmod(-1)     = 0.88 + 0.27 = 1.14
# ### sigmod(2)       +             sigmod(-1)     = 0.88 + 0.26 = 1.14
# ### sigmod(4)       +             sigmod(-2)     = 0.98 + 0.12 = 1

# %% [markdown]
# # 作业：试调整 w1,w2,w3,w4,并修改w5,w6,使输出符合xor函数
# # 提示：先修改NNWadd函数使之符合下图的结构

# %% [markdown]
# ![](xorann.png)
